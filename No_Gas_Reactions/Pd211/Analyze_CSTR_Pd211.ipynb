# %%
import os
import glob
import itertools
from random import randint
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from pathlib import Path
import time

import matplotlib.cm as cm
from IPython.display import Image
import git

from rmgpy.molecule import Molecule
from rmgpy.data.base import Database

# %%
#Input file
rmg_model_path = '../../../Pd211/'
analysis_path = '../Pd211/results/'

# %%
#Git-python: checkout master branch
import git
repo = git.Repo(rmg_model_path)
date = time.localtime(repo.head.commit.committed_date)
git_date = f"{date[0]}_{date[1]}_{date[2]}_{date[3]}{date[4]}"
git_sha = str(repo.head.commit)[0:6]
git_msg = str(repo.head.commit.message)[0:50].replace(" ", "_").replace("'", "_").replace("\n", "")

current_commit = f"{git_date}_{git_sha}_{git_msg}"

current_commit
# Out:
# '2021_6_21_013_04eec2_master_Pd211_26rxn'

# %%
# #checkout 1 commit back
# repo.git.checkout('HEAD^1')
# sha = str(repo.head.commit)
# msg = str(repo.head.commit.message)
# print(sha,': ', msg)

# #checkout 2 commit back
# repo = git.Repo('/work/westgroup/lee.ting/cantera/ammonia/')
# repo.git.checkout('HEAD^1')
# sha = repo.head.commit
# msg = repo.head.commit.message
# print(sha,': ', msg)

# %%
commit_list = []

# read in each filename into dictionary. get a list of the commit folders in this repo
for path in Path(analysis_path).rglob('*.csv'):
    path_str = str(path)
    start_index = path_str.find(analysis_path)
    
    if start_index != -1:
        commit = path_str[(start_index+len(analysis_path)):]
        print(commit)
        if "\n" in commit:
            end_char = commit.index("\n")
        else: 
            end_char = commit.index("/")
        
        commit = commit[:end_char]
        if commit not in commit_list:
            commit_list.append(commit)
        
print(commit_list)
# Out:
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1000.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1009.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1018.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1027.2727272727275_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1036.3636363636365_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1045.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1054.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1063.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1072.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1081.818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1090.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1100.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1109.090909090909_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1118.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1127.2727272727275_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1136.3636363636365_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1145.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1154.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1163.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1172.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1181.818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1190.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1200.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1209.090909090909_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1218.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1227.2727272727275_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1236.3636363636365_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1245.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1254.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1263.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1272.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1281.818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1290.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1300.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_409.09090909090907_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_418.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_427.27272727272725_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_436.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_445.45454545454544_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_454.54545454545456_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_463.6363636363636_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_472.72727272727275_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_481.8181818181818_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_490.90909090909093_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_500.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_509.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_518.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_527.2727272727273_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_536.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_545.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_554.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_563.6363636363636_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_572.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_581.8181818181819_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_590.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_600.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_609.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_618.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_627.2727272727273_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_636.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_645.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_654.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_663.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_672.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_681.8181818181819_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_690.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_700.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_709.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_718.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_727.2727272727273_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_736.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_745.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_754.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_763.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_772.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_781.8181818181819_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_790.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_800.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_809.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_818.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_827.2727272727273_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_836.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_845.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_854.5454545454545_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_863.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_872.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_881.8181818181819_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_890.909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_900.0_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_909.0909090909091_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_918.1818181818182_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_927.2727272727274_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_936.3636363636364_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_945.4545454545455_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_954.5454545454546_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_963.6363636363637_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_972.7272727272727_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_981.8181818181819_O2_0_02_NH3_0_001.csv
# 2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_990.909090909091_O2_0_02_NH3_0_001.csv
# ['2021_6_21_013_04eec2_master_Pd211_26rxn']

# %%
data_dict = {}

# Read last line from each CSV file to get the outlet concentrations from the PFR
# if "one_commit" is true, only run the master commit 
one_commit = False
if one_commit == True:
    commit_list = [current_commit]
    
for commit in commit_list:
    first_file = True
    for path in Path(f"../Pd211/results/{current_commit}").rglob('*.csv'):
        path_str = str(path)
        if os.stat(path_str).st_size >= 1e6:
            if first_file == True: 
                data = pd.read_csv(path_str)
                aggdata = data.tail(1)
                first_file = False
            else: 
                data = pd.read_csv(path_str)
                aggdata = aggdata.append(data.tail(1))
            data_dict.update({commit:aggdata})
        else:
            print(path_str)
# Out:
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1009.0909090909091_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1018.1818181818182_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1063.6363636363637_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1072.7272727272727_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1081.818181818182_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1145.4545454545455_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1218.1818181818182_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1227.2727272727275_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1245.4545454545455_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_1254.5454545454545_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_436.3636363636364_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_490.90909090909093_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_500.0_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_509.0909090909091_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_518.1818181818182_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_536.3636363636364_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_572.7272727272727_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_609.0909090909091_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_654.5454545454545_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_681.8181818181819_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_690.909090909091_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_745.4545454545455_O2_0_02_NH3_0_001.csv
# ../Pd211/results/2021_6_21_013_04eec2_master_Pd211_26rxn/IdealGasReactor/energy_off/sensitivity_off/results/Spinning_basket_area_0.01_energy_off_temp_772.7272727272727_O2_0_02_NH3_0_001.csv

# %% [markdown]
# # For our selectivity definitions
# Two types of selectivity. Overall, and instantaneous.
#
# For overall selectivity, it depends on the total amounts exiting the packed bed. Probably what is measured experimentally from the PBR experiment (by measuring concentrations leaving the bed).
#
# $$ selectivity(N2) = \frac{2 * moles_{N2}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# The 2 is because we are preserving (and counting) atoms of Nitrogen. Selectivity is "What percentage of N atoms (from consuming ammonia) ended up as N2?
# "
#
# $$ selectivity(N2O) = \frac{2 * moles_{N2O}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
# $$ selectivity(NO) = \frac{moles_{NO}}{molesfed_{NH3} - moles_{NH3}} * 100\%$$
#
#
# For instantaneous selectivity, it changes at different points in the packed bed.
# If we want the instantaneous selectivity evaluated at the exit of the bed, evaluate these expressions at the end of the bed (the last row):
#
# $$ selectivity(N2)  = \frac{ 2 * net rate of production of N2}{-1 * net rate of production of NH3}$$
# $$ selectivity(N2O)  = \frac{ 2 * net rate of production of N2O}{-1 * net rate of production of NH3}$$
# $$ selectivity(NO)  = \frac{  net rate of production of NO}{-1 * net rate of production of NH3}$$

# %%
for commit in commit_list:
    data_dict[commit]['NH3(6) conversion (%)']= 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])/data_dict[commit]['X_nh3 initial']
    
    S_N2 = (-2)*(data_dict[commit]['N2(4) ROP [kmol/m^3 s]']+data_dict[commit]['N2(4) surface ROP [kmol/m^2 s]'])
    S_NO = (-1)*(data_dict[commit]['NO(5) ROP [kmol/m^3 s]']+data_dict[commit]['NO(5) surface ROP [kmol/m^2 s]'])
    S_N2O = (-2)*(data_dict[commit]['N2O(7) ROP [kmol/m^3 s]']+data_dict[commit]['N2O(7) surface ROP [kmol/m^2 s]'])
    
    data_dict[commit]['N2(4) Selectivity (%)'] = 100*S_N2 / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['NO(5) Selectivity (%)'] = 100*S_NO / (S_N2 + S_NO + S_N2O)
    data_dict[commit]['N2O(7) Selectivity (%)'] = 100*S_N2O / (S_N2 + S_NO + S_N2O)

    data_dict[commit]['OX Coverage']=data_dict[commit]['OX']/(data_dict[commit]['OX'] + data_dict[commit]['NX'] + data_dict[commit]['NOX']+  data_dict[commit]['X(1)'])
    data_dict[commit]['NOX Coverage']=data_dict[commit]['NOX']/(data_dict[commit]['OX'] + data_dict[commit]['NX'] + data_dict[commit]['NOX']+  data_dict[commit]['X(1)'])
    data_dict[commit]['NX Coverage']=data_dict[commit]['NX']/(data_dict[commit]['OX'] + data_dict[commit]['NX'] + data_dict[commit]['NOX']+  data_dict[commit]['X(1)'])
    data_dict[commit]['X Coverage']=data_dict[commit]['X(1)']/(data_dict[commit]['OX'] + data_dict[commit]['NX'] + data_dict[commit]['NOX']+  data_dict[commit]['X(1)'])

# %%
data_dict[commit].to_csv("schnedier_Pd211.csv")
data_dict[commit]
# Out:
#             T (K)    P (Pa)  V (M^3/s)  X_nh3 initial  X_o2 initial  \
# 9999  1000.000000  101325.0     0.0001          0.001          0.02
# 9999  1027.272727  101325.0     0.0001          0.001          0.02
# 9999  1036.363636  101325.0     0.0001          0.001          0.02
# 9999  1045.454545  101325.0     0.0001          0.001          0.02
# 9999  1054.545455  101325.0     0.0001          0.001          0.02
# ...           ...       ...        ...            ...           ...
# 9999   954.545455  101325.0     0.0001          0.001          0.02
# 9999   963.636364  101325.0     0.0001          0.001          0.02
# 9999   972.727273  101325.0     0.0001          0.001          0.02
# 9999   981.818182  101325.0     0.0001          0.001          0.02
# 9999   990.909091  101325.0     0.0001          0.001          0.02
#
#       X_h2o initial  X_he initial  (NH3/O2)  T (K) final          Rtol  ...  \
# 9999           0.05         0.929      0.05  1000.000000  1.000000e-11  ...
# 9999           0.05         0.929      0.05  1027.272727  1.000000e-11  ...
# 9999           0.05         0.929      0.05  1036.363636  1.000000e-11  ...
# 9999           0.05         0.929      0.05  1045.454545  1.000000e-11  ...
# 9999           0.05         0.929      0.05  1054.545455  1.000000e-11  ...
# ...             ...           ...       ...          ...           ...  ...
# 9999           0.05         0.929      0.05   954.545455  1.000000e-11  ...
# 9999           0.05         0.929      0.05   963.636364  1.000000e-11  ...
# 9999           0.05         0.929      0.05   972.727273  1.000000e-11  ...
# 9999           0.05         0.929      0.05   981.818182  1.000000e-11  ...
# 9999           0.05         0.929      0.05   990.909091  1.000000e-11  ...
#
#       H2O(3) + 2 X(1) <=> H_X(12) + OHX ROP [kmol/m^2 s]  \
# 9999                                      -1.797697e-08
# 9999                                      -4.111513e-08
# 9999                                      -5.322014e-08
# 9999                                      -6.819222e-08
# 9999                                      -8.641340e-08
# ...                                                 ...
# 9999                                      -3.938398e-09
# 9999                                      -5.397000e-09
# 9999                                      -7.357575e-09
# 9999                                      -9.973328e-09
# 9999                                      -1.343520e-08
#
#      N2(4) + X(1) <=> NN_ads(36) ROP [kmol/m^2 s] NH3(6) conversion (%)  \
# 9999                                -1.455838e-22              5.110288
# 9999                                 9.449711e-21              9.744294
# 9999                                 2.276401e-21             11.993032
# 9999                                -1.265255e-20             14.686828
# 9999                                 8.470329e-22             17.877363
# ...                                           ...                   ...
# 9999                                -5.624828e-23              1.657199
# 9999                                -7.014492e-22              2.084275
# 9999                                 1.654361e-22              2.616369
# 9999                                -2.448455e-22              3.277705
# 9999                                -8.801202e-22              4.097439
#
#       N2(4) Selectivity (%)  NO(5) Selectivity (%)  N2O(7) Selectivity (%)  \
# 9999              96.866608               3.133391            1.199094e-07
# 9999              97.204992               2.795008            1.305018e-07
# 9999              97.316186               2.683814            1.340405e-07
# 9999              97.424850               2.575150            1.375900e-07
# 9999              97.529911               2.470089            1.411532e-07
# ...                     ...                    ...                     ...
# 9999              96.346552               3.653448            1.019868e-07
# 9999              96.441230               3.558770            1.056331e-07
# 9999              96.541752               3.458248            1.092399e-07
# 9999              96.646881               3.353119            1.128161e-07
# 9999              96.755507               3.244492            1.163701e-07
#
#       OX Coverage  NOX Coverage   NX Coverage  X Coverage
# 9999     0.990280      0.000026  3.052263e-08    0.009693
# 9999     0.985314      0.000022  4.055081e-08    0.014664
# 9999     0.983221      0.000021  4.444031e-08    0.016757
# 9999     0.980874      0.000020  4.859533e-08    0.019106
# 9999     0.978248      0.000019  5.299363e-08    0.021733
# ...           ...           ...           ...         ...
# 9999     0.995301      0.000036  1.867487e-08    0.004663
# 9999     0.994548      0.000033  2.062807e-08    0.005419
# 9999     0.993683      0.000031  2.277334e-08    0.006285
# 9999     0.992694      0.000030  2.512671e-08    0.007276
# 9999     0.991565      0.000028  2.770448e-08    0.008407
#
# [76 rows x 98 columns]

# %%
data_dict[commit].plot.scatter(x='T (K)',y='NH3(6) conversion (%)',label='NH3(6) conversion (%)',color="r")
# Out:
# <AxesSubplot:xlabel='T (K)', ylabel='NH3(6) conversion (%)'>

# %%
ax1 = data_dict[commit].plot.scatter(x='T (K)',y='N2O(7) Selectivity (%)',
                                     label='N2O',color='g')
ax2 = data_dict[commit].plot.scatter(x='T (K)',y='N2(4) Selectivity (%)',
                                     label='N2',color="orange", ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='T (K)',y='NO(5) Selectivity (%)',
                                     label='NO',color='blue', ax=ax1)
ax1.set_xlabel("Temperature (K)")
ax1.set_ylabel("Selectivity (%)")
ax1.set_xlim(400, 1300)
plt.show()

# %%
ax1 = data_dict[commit].plot.scatter(x='T (K)',y='OX Coverage',
                                     label='OX',color="orange")
ax2 = data_dict[commit].plot.scatter(x='T (K)',y='NOX Coverage',
                                      label='NOX',color='g', ax=ax1)
ax3 = data_dict[commit].plot.scatter(x='T (K)',y='NX Coverage',
                                     label='NX',color='blue', ax=ax1)
ax4 = data_dict[commit].plot.scatter(x='T (K)',y='X Coverage',
                                      label='X(1)',color='r', ax=ax1)
ax1.set_xlabel("Temperature (K)")
ax1.set_ylabel("Coverage")
plt.show()

# %% [markdown]
# ### Use this if run RMG on master

# %%
for commit in commit_list:
    for i in conversion_species:
        data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
    
    for i in selectivity_species:
        data_dict[commit][f'{i} Selectivity (%)'] = 100*(data_dict[commit][i])/(data_dict[commit]['X_nh3 initial'] - data_dict[commit]['NH3(6)'])

    for i in coverage_species_1:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['OX(10)'] + data_dict[commit]['HOX(13)']+ data_dict[commit]['X(1)'])
    
    for i in coverage_species_2:
        data_dict[commit][f'{i} Coverage'] = (data_dict[commit][i])/(data_dict[commit]['NO_ads(27)'] + data_dict[commit]['N_ads(64)']+ data_dict[commit]['H3NX(29)']+ data_dict[commit]['X(1)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-4889769d6bc7> in <module>
#       1 for commit in commit_list:
# ----> 2     for i in conversion_species:
#       3         data_dict[commit]['NH3(6) conversion (%)'] = 100*(data_dict[commit]['X_nh3 initial'] - data_dict[commit][i])/data_dict[commit]['X_nh3 initial']
#       4
#       5     for i in selectivity_species:
#
# NameError: name 'conversion_species' is not defined

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='OX(10) Coverage',
                                     label='O_X',color="orange")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='HOX(13) Coverage',
                                     label='OH_X',color='g', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='X(1) Coverage',
                                     label='X',color='blue', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage (%)")
plt.show()

# %%
ax1 = data_dict[commit].plot(x='X_nh3 initial',y='NO_ads(27) Coverage',
                                     label='NO_X',color="r")
ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N_ads(72) Coverage',
                                     label='N_X',color='orange', ax=ax1)
ax3 = data_dict[commit].plot(x='X_nh3 initial',y='H3NX(29) Coverage',
                                     label='NH3_X',color='b', ax=ax1)
ax4 = data_dict[commit].plot(x='X_nh3 initial',y='X Coverage',
                                     label='X',color='g', ax=ax1)
ax1.set_xlabel("NH3(6) partial pressure (atm)")
ax1.set_ylabel("Coverage (%)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NO_ads(27) Coverage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-2d1a4e9fe8bf> in <module>
#       1 ax1 = data_dict[commit].plot(x='X_nh3 initial',y='NO_ads(27) Coverage',
# ----> 2                                      label='NO_X',color="r")
#       3 ax2 = data_dict[commit].plot(x='X_nh3 initial',y='N_ads(72) Coverage',
#       4                                      label='N_X',color='orange', ax=ax1)
#       5 ax3 = data_dict[commit].plot(x='X_nh3 initial',y='H3NX(29) Coverage',
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     933
#     934                 # don't overwrite
# --> 935                 data = data[y].copy()
#     936
#     937                 if isinstance(data, ABCSeries):
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.conda/envs/rmg_env/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'NO_ads(27) Coverage'
